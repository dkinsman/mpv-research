# %%
import numpy as np
import pandas as pd
import json
from geojson import Point, Feature, FeatureCollection, dump
import pickle
import os

# %%
df = pd.read_csv('../raw/mpv-data.csv')
print(df.shape)
df = df[['latitude','longitude', 'state', 'date']]
state = df.state.unique().tolist()
df['date'] = pd.to_datetime(df['date'])

with open('../clean/statelist.pkl', "wb") as f:
            pickle.dump(state, f)
        
#df['date'] = df['date'].dt.strftime('%Y-%m-%d')
print(df.dtypes)
df.head()
# Out:
# (10454, 62)
# latitude            float64
# longitude           float64
# state                object
# date         datetime64[ns]
# dtype: object
#     latitude   longitude state       date
# 0  41.000000  -75.360000    PA 2022-06-23
# 1  42.250000  -84.760000    MI 2022-06-22
# 2  37.412169 -121.960331    CA 2022-06-22
# 3  36.891971  -76.302463    VA 2022-06-21
# 4  40.720000  -84.090000    OH 2022-06-21

# %%
df_states = []

years = list(range(2013,2023))
print(years)
# Out:
# [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
for index, i in enumerate(state):
    print ("State:  ", i)
    df_states.append(df[df.state==i])
    print(df_states[index].shape)
    #df_i.dropna(subset = ['longitude'], axis = 0, how = 'all', inplace = True)
    #df_i.dropna(subset = ['latitude'], axis = 0, how = 'all', inplace = True)
    target_directory = '../clean/pd_data/' + i 
    #print(target_directory)
    
    if df_states[index].shape[0] <= 151:
        target_directory += '/lat_long.pkl'
        df_states[index].drop(['date', 'state'], axis =1, inplace = True)
        lat_long = df_states[index].values.tolist()
        with open(target_directory, "wb") as f:
            pickle.dump(lat_long, f)
    
    else:
        for j in years:
            target_directory = '../clean/pd_data/' + i
            dff = df_states[index][df_states[index].date.dt.year == j]
            lat_long = dff.drop(['date', 'state'], axis =1)
            lat_long = lat_long.values.tolist()
            target_directory += '/lat_long' + str(j) + '.pkl' 
            with open(target_directory, "wb") as f:
                pickle.dump(lat_long, f) 


#df = df[['latitude'], ['longitude']]
#print(df_mi.dtypes)
#print(df_mi.shape)
#df = df.fillna(np.nan).replace([np.nan], [None])
#df_mi.dropna(subset = ['longitude'], axis = 0, how = 'all', inplace = True)
#df_mi.dropna(subset = ['latitude'], axis = 0, how = 'all', inplace = True)


#df.to_csv('../clean/lat_long.csv')
#df_13 = df[(df['date'] > '2013-01-01') & (df['date'] < '2014-01-01')]
#df_13
#df_14 = df[(df['date'] > '2014-01-01') & (df['date'] < '2015-01-01')]
#df_13
#lat_long_mi= df_mi.values.tolist()
# Out:
# State:   PA
# (230, 4)
# State:   MI
# (177, 4)
# State:   CA
# (1560, 4)
# State:   VA
# (172, 4)
# State:   OH
# (279, 4)
# State:   ME
# (45, 4)
# State:   MD
# (171, 4)
# State:   NH
# (26, 4)
# State:   TX
# (960, 4)
# State:   AK
# (63, 4)
# State:   NM
# (207, 4)
# State:   AZ
# (461, 4)
# State:   OK
# (278, 4)
# State:   OR
# (157, 4)
# State:   TN
# (265, 4)
# State:   WV
# (90, 4)
# State:   FL
# (723, 4)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# State:   NC
# (287, 4)
# State:   ID
# (75, 4)
# State:   WA
# (288, 4)
# State:   GA
# (398, 4)
# State:   CO
# (326, 4)
# State:   AL
# (197, 4)
# State:   WI
# (147, 4)
# State:   IA
# (62, 4)
# State:   AR
# (136, 4)
# State:   NJ
# (132, 4)
# State:   SC
# (168, 4)
# State:   IL
# (237, 4)
# State:   KY
# (174, 4)
# State:   MT
# (62, 4)
# State:   MO
# (275, 4)
# State:   WY
# (31, 4)
# State:   KS
# (100, 4)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# State:   LA
# (207, 4)
# State:   IN
# (177, 4)
# State:   MA
# (76, 4)
# State:   NY
# (218, 4)
# State:   MS
# (145, 4)
# State:   MN
# (111, 4)
# State:   RI
# (9, 4)
# State:   DC
# (36, 4)
# State:   ND
# (19, 4)
# State:   SD
# (34, 4)
# State:   NV
# (166, 4)
# State:   UT
# (115, 4)
# State:   DE
# (25, 4)
# State:   NE
# (52, 4)
# State:   CT
# (44, 4)
# State:   HI
# (46, 4)
# State:   VT
# (15, 4)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_8832/3707816051.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_states[index].drop(['date', 'state'], axis =1, inplace = True)
