# %%
import pandas as pd
import numpy as np
import gudhi as gd
import os
import pickle 
import gudhi.representations
import matplotlib.pyplot as plt

# %%
with open('../clean/statelist.pkl', 'rb') as f:
    state = pickle.load(f)
    
state1 = state[:25]
state2 = state[25:]

print(len(state1))
print(len(state2))
# Out:
# 25
# 26

# %%
directory = '../clean/pd_data'
ll = []
years = list(range(2013,2023))

for files in os.walk(directory):
    if files[2] == ['lat_long.pkl']:
        #print(files)
        dir = files[0] + r'/lat_long.pkl'
        print(dir)
        state = files[0][-2:]
        with open(dir, 'rb') as f:
            lat_long = pickle.load(f)
        
        stree = gd.RipsComplex(points = lat_long).create_simplex_tree()
        dgm = stree.persistence(persistence_dim_max = True)
        plt.figure()
        gd.plot_persistence_diagram(dgm, legend = True)
        plt.title('Persistance diagram ' + state + ' (rips)')
        plt.savefig('../output/pd/'+ state + r'/rips_pd.jpeg', bbox_inches = 'tight')
    else:
        for i in years:
            if len(files[2]) > 1:
                i = str(i)
                state = files[0][-2:]
                dir = files[0] + '/lat_long' + i + '.pkl'
                print(dir)
                with open(dir, 'rb') as f:
                    lat_long = pickle.load(f)
    
                stree = gd.RipsComplex(points = lat_long).create_simplex_tree()
                dgm = stree.persistence(persistence_dim_max = True)
                plt.figure()
                gd.plot_persistence_diagram(dgm, legend = True)
                plt.title('Persistance diagram ' + state + ' (' + i + ' rips)')
                plt.savefig('../output/pd/'+ state + r'/rips_' + i + 'pd.jpeg', bbox_inches = 'tight')


#type(lat_long)

# %%
directory = '../clean/pd_data'
ll = []
years = list(range(2013,2023))

for files in os.walk(directory):
    if files[2] == ['lat_long.pkl']:
        #print(files)
        dir = files[0] + r'/lat_long.pkl'
        print(dir)
        state = files[0][-2:]
        with open(dir, 'rb') as f:
            lat_long = pickle.load(f)
        
        stree = gd.AlphaComplex(points = lat_long).create_simplex_tree()
        dgm = stree.persistence(persistence_dim_max = True)
        
        gd.plot_persistence_diagram(dgm, legend = True)
        plt.title('Persistence diagram ' + state + ' (alpha)')
        plt.savefig('../output/pd/'+ state + r'/alpha_pd.jpeg', bbox_inches = 'tight')
# Out:
# ../clean/pd_data/lat_long.pkl
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       9 print(dir)
#      10 state = files[0][-2:]
# ---> 11 with open(dir, 'rb') as f:
#      12     lat_long = pickle.load(f)
#      14 stree = gd.AlphaComplex(points = lat_long).create_simplex_tree()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../clean/pd_data/lat_long.pkl'

# %%
directory = '../clean/pd_data'
ll = []
years = list(range(2013,2023))

for files in os.walk(directory):
    if files[2] != ['lat_long.pkl']:
        for i in years:
            if len(files[2]) > 1:
                i = str(i)
                state = files[0][-2:]
                dir = files[0] + '/lat_long' + i + '.pkl'
                print(dir)
                with open(dir, 'rb') as f:
                    lat_long = pickle.load(f)
# Out:
# ../clean/pd_data/VA/lat_long2013.pkl
# ../clean/pd_data/VA/lat_long2014.pkl
# ../clean/pd_data/VA/lat_long2015.pkl
# ../clean/pd_data/VA/lat_long2016.pkl
# ../clean/pd_data/VA/lat_long2017.pkl
# ../clean/pd_data/VA/lat_long2018.pkl
# ../clean/pd_data/VA/lat_long2019.pkl
# ../clean/pd_data/VA/lat_long2020.pkl
# ../clean/pd_data/VA/lat_long2021.pkl
# ../clean/pd_data/VA/lat_long2022.pkl
# ../clean/pd_data/SC/lat_long2013.pkl
# ../clean/pd_data/SC/lat_long2014.pkl
# ../clean/pd_data/SC/lat_long2015.pkl
# ../clean/pd_data/SC/lat_long2016.pkl
# ../clean/pd_data/SC/lat_long2017.pkl
# ../clean/pd_data/SC/lat_long2018.pkl
# ../clean/pd_data/SC/lat_long2019.pkl
# ../clean/pd_data/SC/lat_long2020.pkl
# ../clean/pd_data/SC/lat_long2021.pkl
# ../clean/pd_data/SC/lat_long2022.pkl
# ../clean/pd_data/GA/lat_long2013.pkl
# ../clean/pd_data/GA/lat_long2014.pkl
# ../clean/pd_data/GA/lat_long2015.pkl
# ../clean/pd_data/GA/lat_long2016.pkl
# ../clean/pd_data/GA/lat_long2017.pkl
# ../clean/pd_data/GA/lat_long2018.pkl
# ../clean/pd_data/GA/lat_long2019.pkl
# ../clean/pd_data/GA/lat_long2020.pkl
# ../clean/pd_data/GA/lat_long2021.pkl
# ../clean/pd_data/GA/lat_long2022.pkl
# ../clean/pd_data/MO/lat_long2013.pkl
# ../clean/pd_data/MO/lat_long2014.pkl
# ../clean/pd_data/MO/lat_long2015.pkl
# ../clean/pd_data/MO/lat_long2016.pkl
# ../clean/pd_data/MO/lat_long2017.pkl
# ../clean/pd_data/MO/lat_long2018.pkl
# ../clean/pd_data/MO/lat_long2019.pkl
# ../clean/pd_data/MO/lat_long2020.pkl
# ../clean/pd_data/MO/lat_long2021.pkl
# ../clean/pd_data/MO/lat_long2022.pkl
# ../clean/pd_data/KY/lat_long2013.pkl
# ../clean/pd_data/KY/lat_long2014.pkl
# ../clean/pd_data/KY/lat_long2015.pkl
# ../clean/pd_data/KY/lat_long2016.pkl
# ../clean/pd_data/KY/lat_long2017.pkl
# ../clean/pd_data/KY/lat_long2018.pkl
# ../clean/pd_data/KY/lat_long2019.pkl
# ../clean/pd_data/KY/lat_long2020.pkl
# ../clean/pd_data/KY/lat_long2021.pkl
# ../clean/pd_data/KY/lat_long2022.pkl
# ../clean/pd_data/AL/lat_long2013.pkl
# ../clean/pd_data/AL/lat_long2014.pkl
# ../clean/pd_data/AL/lat_long2015.pkl
# ../clean/pd_data/AL/lat_long2016.pkl
# ../clean/pd_data/AL/lat_long2017.pkl
# ../clean/pd_data/AL/lat_long2018.pkl
# ../clean/pd_data/AL/lat_long2019.pkl
# ../clean/pd_data/AL/lat_long2020.pkl
# ../clean/pd_data/AL/lat_long2021.pkl
# ../clean/pd_data/AL/lat_long2022.pkl
# ../clean/pd_data/MI/lat_long2013.pkl
# ../clean/pd_data/MI/lat_long2014.pkl
# ../clean/pd_data/MI/lat_long2015.pkl
# ../clean/pd_data/MI/lat_long2016.pkl
# ../clean/pd_data/MI/lat_long2017.pkl
# ../clean/pd_data/MI/lat_long2018.pkl
# ../clean/pd_data/MI/lat_long2019.pkl
# ../clean/pd_data/MI/lat_long2020.pkl
# ../clean/pd_data/MI/lat_long2021.pkl
# ../clean/pd_data/MI/lat_long2022.pkl
# ../clean/pd_data/OK/lat_long2013.pkl
# ../clean/pd_data/OK/lat_long2014.pkl
# ../clean/pd_data/OK/lat_long2015.pkl
# ../clean/pd_data/OK/lat_long2016.pkl
# ../clean/pd_data/OK/lat_long2017.pkl
# ../clean/pd_data/OK/lat_long2018.pkl
# ../clean/pd_data/OK/lat_long2019.pkl
# ../clean/pd_data/OK/lat_long2020.pkl
# ../clean/pd_data/OK/lat_long2021.pkl
# ../clean/pd_data/OK/lat_long2022.pkl
# ../clean/pd_data/IN/lat_long2013.pkl
# ../clean/pd_data/IN/lat_long2014.pkl
# ../clean/pd_data/IN/lat_long2015.pkl
# ../clean/pd_data/IN/lat_long2016.pkl
# ../clean/pd_data/IN/lat_long2017.pkl
# ../clean/pd_data/IN/lat_long2018.pkl
# ../clean/pd_data/IN/lat_long2019.pkl
# ../clean/pd_data/IN/lat_long2020.pkl
# ../clean/pd_data/IN/lat_long2021.pkl
# ../clean/pd_data/IN/lat_long2022.pkl
# ../clean/pd_data/CO/lat_long2013.pkl
# ../clean/pd_data/CO/lat_long2014.pkl
# ../clean/pd_data/CO/lat_long2015.pkl
# ../clean/pd_data/CO/lat_long2016.pkl
# ../clean/pd_data/CO/lat_long2017.pkl
# ../clean/pd_data/CO/lat_long2018.pkl
# ../clean/pd_data/CO/lat_long2019.pkl
# ../clean/pd_data/CO/lat_long2020.pkl
# ../clean/pd_data/CO/lat_long2021.pkl
# ../clean/pd_data/CO/lat_long2022.pkl
# ../clean/pd_data/CA/lat_long2013.pkl
# ../clean/pd_data/CA/lat_long2014.pkl
# ../clean/pd_data/CA/lat_long2015.pkl
# ../clean/pd_data/CA/lat_long2016.pkl
# ../clean/pd_data/CA/lat_long2017.pkl
# ../clean/pd_data/CA/lat_long2018.pkl
# ../clean/pd_data/CA/lat_long2019.pkl
# ../clean/pd_data/CA/lat_long2020.pkl
# ../clean/pd_data/CA/lat_long2021.pkl
# ../clean/pd_data/CA/lat_long2022.pkl
# ../clean/pd_data/FL/lat_long2013.pkl
# ../clean/pd_data/FL/lat_long2014.pkl
# ../clean/pd_data/FL/lat_long2015.pkl
# ../clean/pd_data/FL/lat_long2016.pkl
# ../clean/pd_data/FL/lat_long2017.pkl
# ../clean/pd_data/FL/lat_long2018.pkl
# ../clean/pd_data/FL/lat_long2019.pkl
# ../clean/pd_data/FL/lat_long2020.pkl
# ../clean/pd_data/FL/lat_long2021.pkl
# ../clean/pd_data/FL/lat_long2022.pkl
# ../clean/pd_data/TX/lat_long2013.pkl
# ../clean/pd_data/TX/lat_long2014.pkl
# ../clean/pd_data/TX/lat_long2015.pkl
# ../clean/pd_data/TX/lat_long2016.pkl
# ../clean/pd_data/TX/lat_long2017.pkl
# ../clean/pd_data/TX/lat_long2018.pkl
# ../clean/pd_data/TX/lat_long2019.pkl
# ../clean/pd_data/TX/lat_long2020.pkl
# ../clean/pd_data/TX/lat_long2021.pkl
# ../clean/pd_data/TX/lat_long2022.pkl
# ../clean/pd_data/PA/lat_long2013.pkl
# ../clean/pd_data/PA/lat_long2014.pkl
# ../clean/pd_data/PA/lat_long2015.pkl
# ../clean/pd_data/PA/lat_long2016.pkl
# ../clean/pd_data/PA/lat_long2017.pkl
# ../clean/pd_data/PA/lat_long2018.pkl
# ../clean/pd_data/PA/lat_long2019.pkl
# ../clean/pd_data/PA/lat_long2020.pkl
# ../clean/pd_data/PA/lat_long2021.pkl
# ../clean/pd_data/PA/lat_long2022.pkl
# ../clean/pd_data/NC/lat_long2013.pkl
# ../clean/pd_data/NC/lat_long2014.pkl
# ../clean/pd_data/NC/lat_long2015.pkl
# ../clean/pd_data/NC/lat_long2016.pkl
# ../clean/pd_data/NC/lat_long2017.pkl
# ../clean/pd_data/NC/lat_long2018.pkl
# ../clean/pd_data/NC/lat_long2019.pkl
# ../clean/pd_data/NC/lat_long2020.pkl
# ../clean/pd_data/NC/lat_long2021.pkl
# ../clean/pd_data/NC/lat_long2022.pkl
# ../clean/pd_data/NM/lat_long2013.pkl
# ../clean/pd_data/NM/lat_long2014.pkl
# ../clean/pd_data/NM/lat_long2015.pkl
# ../clean/pd_data/NM/lat_long2016.pkl
# ../clean/pd_data/NM/lat_long2017.pkl
# ../clean/pd_data/NM/lat_long2018.pkl
# ../clean/pd_data/NM/lat_long2019.pkl
# ../clean/pd_data/NM/lat_long2020.pkl
# ../clean/pd_data/NM/lat_long2021.pkl
# ../clean/pd_data/NM/lat_long2022.pkl
# ../clean/pd_data/NV/lat_long2013.pkl
# ../clean/pd_data/NV/lat_long2014.pkl
# ../clean/pd_data/NV/lat_long2015.pkl
# ../clean/pd_data/NV/lat_long2016.pkl
# ../clean/pd_data/NV/lat_long2017.pkl
# ../clean/pd_data/NV/lat_long2018.pkl
# ../clean/pd_data/NV/lat_long2019.pkl
# ../clean/pd_data/NV/lat_long2020.pkl
# ../clean/pd_data/NV/lat_long2021.pkl
# ../clean/pd_data/NV/lat_long2022.pkl
# ../clean/pd_data/MD/lat_long2013.pkl
# ../clean/pd_data/MD/lat_long2014.pkl
# ../clean/pd_data/MD/lat_long2015.pkl
# ../clean/pd_data/MD/lat_long2016.pkl
# ../clean/pd_data/MD/lat_long2017.pkl
# ../clean/pd_data/MD/lat_long2018.pkl
# ../clean/pd_data/MD/lat_long2019.pkl
# ../clean/pd_data/MD/lat_long2020.pkl
# ../clean/pd_data/MD/lat_long2021.pkl
# ../clean/pd_data/MD/lat_long2022.pkl
# ../clean/pd_data/AZ/lat_long2013.pkl
# ../clean/pd_data/AZ/lat_long2014.pkl
# ../clean/pd_data/AZ/lat_long2015.pkl
# ../clean/pd_data/AZ/lat_long2016.pkl
# ../clean/pd_data/AZ/lat_long2017.pkl
# ../clean/pd_data/AZ/lat_long2018.pkl
# ../clean/pd_data/AZ/lat_long2019.pkl
# ../clean/pd_data/AZ/lat_long2020.pkl
# ../clean/pd_data/AZ/lat_long2021.pkl
# ../clean/pd_data/AZ/lat_long2022.pkl
# ../clean/pd_data/NY/lat_long2013.pkl
# ../clean/pd_data/NY/lat_long2014.pkl
# ../clean/pd_data/NY/lat_long2015.pkl
# ../clean/pd_data/NY/lat_long2016.pkl
# ../clean/pd_data/NY/lat_long2017.pkl
# ../clean/pd_data/NY/lat_long2018.pkl
# ../clean/pd_data/NY/lat_long2019.pkl
# ../clean/pd_data/NY/lat_long2020.pkl
# ../clean/pd_data/NY/lat_long2021.pkl
# ../clean/pd_data/NY/lat_long2022.pkl
# ../clean/pd_data/OH/lat_long2013.pkl
# ../clean/pd_data/OH/lat_long2014.pkl
# ../clean/pd_data/OH/lat_long2015.pkl
# ../clean/pd_data/OH/lat_long2016.pkl
# ../clean/pd_data/OH/lat_long2017.pkl
# ../clean/pd_data/OH/lat_long2018.pkl
# ../clean/pd_data/OH/lat_long2019.pkl
# ../clean/pd_data/OH/lat_long2020.pkl
# ../clean/pd_data/OH/lat_long2021.pkl
# ../clean/pd_data/OH/lat_long2022.pkl
# ../clean/pd_data/OR/lat_long2013.pkl
# ../clean/pd_data/OR/lat_long2014.pkl
# ../clean/pd_data/OR/lat_long2015.pkl
# ../clean/pd_data/OR/lat_long2016.pkl
# ../clean/pd_data/OR/lat_long2017.pkl
# ../clean/pd_data/OR/lat_long2018.pkl
# ../clean/pd_data/OR/lat_long2019.pkl
# ../clean/pd_data/OR/lat_long2020.pkl
# ../clean/pd_data/OR/lat_long2021.pkl
# ../clean/pd_data/OR/lat_long2022.pkl
# ../clean/pd_data/IL/lat_long2013.pkl
# ../clean/pd_data/IL/lat_long2014.pkl
# ../clean/pd_data/IL/lat_long2015.pkl
# ../clean/pd_data/IL/lat_long2016.pkl
# ../clean/pd_data/IL/lat_long2017.pkl
# ../clean/pd_data/IL/lat_long2018.pkl
# ../clean/pd_data/IL/lat_long2019.pkl
# ../clean/pd_data/IL/lat_long2020.pkl
# ../clean/pd_data/IL/lat_long2021.pkl
# ../clean/pd_data/IL/lat_long2022.pkl
# ../clean/pd_data/LA/lat_long2013.pkl
# ../clean/pd_data/LA/lat_long2014.pkl
# ../clean/pd_data/LA/lat_long2015.pkl
# ../clean/pd_data/LA/lat_long2016.pkl
# ../clean/pd_data/LA/lat_long2017.pkl
# ../clean/pd_data/LA/lat_long2018.pkl
# ../clean/pd_data/LA/lat_long2019.pkl
# ../clean/pd_data/LA/lat_long2020.pkl
# ../clean/pd_data/LA/lat_long2021.pkl
# ../clean/pd_data/LA/lat_long2022.pkl
# ../clean/pd_data/WA/lat_long2013.pkl
# ../clean/pd_data/WA/lat_long2014.pkl
# ../clean/pd_data/WA/lat_long2015.pkl
# ../clean/pd_data/WA/lat_long2016.pkl
# ../clean/pd_data/WA/lat_long2017.pkl
# ../clean/pd_data/WA/lat_long2018.pkl
# ../clean/pd_data/WA/lat_long2019.pkl
# ../clean/pd_data/WA/lat_long2020.pkl
# ../clean/pd_data/WA/lat_long2021.pkl
# ../clean/pd_data/WA/lat_long2022.pkl
# ../clean/pd_data/TN/lat_long2013.pkl
# ../clean/pd_data/TN/lat_long2014.pkl
# ../clean/pd_data/TN/lat_long2015.pkl
# ../clean/pd_data/TN/lat_long2016.pkl
# ../clean/pd_data/TN/lat_long2017.pkl
# ../clean/pd_data/TN/lat_long2018.pkl
# ../clean/pd_data/TN/lat_long2019.pkl
# ../clean/pd_data/TN/lat_long2020.pkl
# ../clean/pd_data/TN/lat_long2021.pkl
# ../clean/pd_data/TN/lat_long2022.pkl

# %%
rips_complex = gudhi.RipsComplex(points=lat_long,
                                 max_edge_length=24.0)

simplex_tree = rips_complex.create_simplex_tree(max_dimension=2)
result_str = 'Rips complex is of dimension ' + repr(simplex_tree.dimension()) + ' - ' + \
    repr(simplex_tree.num_simplices()) + ' simplices - ' + \
    repr(simplex_tree.num_vertices()) + ' vertices.'
print(result_str)
fmt = '%s -> %.2f'
for filtered_value in simplex_tree.get_filtration():
    print(fmt % tuple(filtered_value))

# %%
stree = gd.RipsComplex(points = lat_long).create_simplex_tree()
dgm = stree.persistence(persistence_dim_max = True)

plt.figure()
gd.plot_persistence_diagram(dgm, legend = True)
plt.title('Persistance diagram')
plt.savefig('../output/pd/dgm_mi.png', bbox_inches = 'tight')

# %%
ac = gd.AlphaComplex(points=lat_long)

stree = ac.create_simplex_tree()
print('Alpha complex is of dimension ', stree.dimension(), ' - ',
  stree.num_simplices(), ' simplices - ', stree.num_vertices(), ' vertices.')

fmt = '%s -> %.2f'
for filtered_value in stree.get_filtration():
    print(fmt % tuple(filtered_value))
stree.dimension()

# %%
stree = gd.AlphaComplex(points = lat_long).create_simplex_tree()
dgm = stree.persistence()
gd.plot_persistence_diagram(dgm, legend = True)
plt.show()

# %%
 stree = gd.AlphaComplex(points = lat_long).create_simplex_tree()
        dgm = stree.persistence(persistence_dim_max = True)
        
        gd.plot_persistence_diagram(dgm, legend = True)
        plt.title('Persistence diagram ' + state + ' (alpha)')
        plt.savefig('../output/pd/'+ state + r'/alpha_pd.jpeg', bbox_inches = 'tight')


                stree = gd.AlphaComplex(points = lat_long).create_simplex_tree()
                dgm = stree.persistence(persistence_dim_max = True)

                gd.plot_persistence_diagram(dgm, legend = True)
                plt.title('Persistence diagram ' + state + ' (' + i + ' alpha)')
                plt.savefig('../output/pd/'+ state + r'/alpha_' +i+ 'pd.jpeg', bbox_inches = 'tight')
