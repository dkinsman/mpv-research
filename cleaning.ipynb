# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mpv-data.csv')
df = df[['date', 'city', 'state', 'race', 'zip', 'county']]
print(df.dtypes)
df['zip'] = df['zip'].astype('Int64')
df['date'] = pd.to_datetime(df['date'])
df
# Out:
# date       object
# city       object
# state      object
# race       object
# zip       float64
# county     object
# dtype: object
#             date              city state      race    zip        county
# 0     2022-06-23  Jackson Township    PA     White  18321        Monroe
# 1     2022-06-22            Albion    MI     Black  49224       Calhoun
# 2     2022-06-22          San Jose    CA  Hispanic  95134   Santa Clara
# 3     2022-06-21           Norfolk    VA     Black  23508  Norfolk city
# 4     2022-06-21              Lima    OH     Black  45804         Allen
# ...          ...               ...   ...       ...    ...           ...
# 10449 2013-01-01        Farmington    NM  Hispanic  87401      San Juan
# 10450 2013-01-01            Omaha     NE     Black  68111       Douglas
# 10451 2013-01-01            Gordon    WI     White  54838       Douglas
# 10452 2013-01-01       Bakersfield    CA  Hispanic  93304          Kern
# ...

# %%
# from https://towardsdatascience.com/the-ultimate-state-county-fips-tool-1e4c54dc9dff
path = "state-county-fips.csv"
fips = pd.read_csv(path)
fips
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [24], in <cell line: 3>()
#       1 # from https://towardsdatascience.com/the-ultimate-state-county-fips-tool-1e4c54dc9dff
#       2 path = "state-county-fips.csv"
# ----> 3 fips = pd.read_csv(path)
#       4 fips
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
